# %%
import requests
import json
import pandas as pd

# %%
def get_catalogs_wb():
    """получение каталога вб"""
    url = 'https://www.wildberries.ru/webapi/menu/main-menu-ru-ru.json'
    headers = {'Accept': "*/*", 'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
    response = requests.get(url, headers=headers)
    data = response.json()
    with open('wb_catalogs_data.json', 'w', encoding='UTF-8') as file:
        json.dump(data, file, indent=2, ensure_ascii=False)
        print(f'Данные сохранены в wb_catalogs_data_sample.json')
    data_list = []
    for d in data:
        try:
            for child in d['childs']:
                try:
                    category_name = child['name']
                    category_url = child['url']
                    shard = child['shard']
                    query = child['query']
                    data_list.append({
                        'category_name': category_name,
                        'category_url': category_url,
                        'shard': shard,
                        'query': query})
                except:
                    continue
                try:
                    for sub_child in child['childs']:
                        category_name = sub_child['name']
                        category_url = sub_child['url']
                        shard = sub_child['shard']
                        query = sub_child['query']
                        data_list.append({
                            'category_name': category_name,
                            'category_url': category_url,
                            'shard': shard,
                            'query': query})
                except:
                    # print(f'не имеет дочерних каталогов *{i["name"]}*')
                    continue
        except:
            # print(f'не имеет дочерних каталогов *{d["name"]}*')
            continue
    return data_list

# %%
def search_category_in_catalog(url, catalog_list):
    """пишем проверку пользовательской ссылки на наличии в каталоге"""
    try:
        for catalog in catalog_list:
            if catalog['category_url'] == url.split('https://www.wildberries.ru')[-1]:
                print(f'найдено совпадение: {catalog["category_name"]}')
                name_category = catalog['category_name']
                shard = catalog['shard']
                query = catalog['query']
                return name_category, shard, query
            else:
                # print('нет совпадения')
                pass
    except:
        print('Данный раздел не найден!')

# %%
def get_data_from_json(json_file):
    """извлекаем из json интересующие нас данные"""
    data_list = []
    for data in json_file['data']['products']:
        try:
            price = int(data["priceU"] / 100)
        except:
            price = 0
        data_list.append({
            'Наименование': data['name'],
            'id': data['id'],
            'Скидка': data['sale'],
            'Цена': price,
            'Цена со скидкой': int(data["salePriceU"] / 100),
            'Бренд': data['brand'],
            'id бренда': int(data['brandId']),
            'feedbacks': data['feedbacks'],
            'rating': data['rating'],
            'Ссылка': f'https://www.wildberries.ru/catalog/{data["id"]}/detail.aspx?targetUrl=BP'
        })
    return data_list

# %%
def get_content(shard, query, low_price=None, top_price=None):
    # вставляем ценовые рамки для уменьшения выдачи, вилбериес отдает только 100 страниц
    headers = {'Accept': "*/*", 'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
    data_list = []
    for page in range(1, 101):
        print(f'Сбор позиций со страницы {page} из 100')
        # url = f'https://wbxcatalog-ru.wildberries.ru/{shard}' \
        #       f'/catalog?appType=1&curr=rub&dest=-1029256,-102269,-1278703,-1255563' \
        #       f'&{query}&lang=ru&locale=ru&sort=sale&page={page}' \
        #       f'&priceU={low_price * 100};{top_price * 100}'
        url = f'https://catalog.wb.ru/catalog/{shard}/catalog?appType=1&curr=rub&dest=-1075831,-77677,-398551,12358499' \
              f'&locale=ru&page={page}&priceU={low_price * 100};{top_price * 100}' \
              f'&reg=0&regions=64,83,4,38,80,33,70,82,86,30,69,1,48,22,66,31,40&sort=popular&spp=0&{query}'
        r = requests.get(url, headers=headers)
        data = r.json()
        print(f'Добавлено позиций: {len(get_data_from_json(data))}')
        if len(get_data_from_json(data)) > 0:
            data_list.extend(get_data_from_json(data))
        else:
            print(f'Сбор данных завершен.')
            break
    return data_list

# %%
def save_excel(data, filename):
    """сохранение результата в excel файл"""
    df = pd.DataFrame(data)
    writer = pd.ExcelWriter(f'{filename}.xlsx')
    df.to_excel(writer, 'data')
    writer.save()
    print(f'Все сохранено в {filename}.xlsx')

# %%
def parser(url, low_price, top_price):
    # получаем список каталогов
    catalog_list = get_catalogs_wb()
    try:
        # поиск введенной категории в общем каталоге
        name_category, shard, query = search_category_in_catalog(url=url, catalog_list=catalog_list)
        # сбор данных в найденном каталоге
        data_list = get_content(shard=shard, query=query, low_price=low_price, top_price=top_price)
        # сохранение найденных данных
        save_excel(data_list, f'{name_category}_from_{low_price}_to_{top_price}')
    except TypeError:
        print('Ошибка! Возможно не верно указан раздел. Удалите все доп фильтры с ссылки')
    except PermissionError:
        print('Ошибка! Вы забыли закрыть созданный ранее excel файл. Закройте и повторите попытку')

# %%
if __name__ == '__main__':

    url = 'https://www.wildberries.ru/catalog/novyy-god/elki'
    low_price = 0
    top_price = 10000000

    parser(url, low_price, top_price)
# Out:
# Данные сохранены в wb_catalogs_data_sample.json
# найдено совпадение: Елки
# Сбор позиций со страницы 1 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 2 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 3 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 4 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 5 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 6 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 7 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 8 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 9 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 10 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 11 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 12 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 13 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 14 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 15 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 16 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 17 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 18 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 19 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 20 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 21 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 22 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 23 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 24 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 25 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 26 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 27 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 28 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 29 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 30 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 31 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 32 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 33 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 34 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 35 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 36 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 37 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 38 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 39 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 40 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 41 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 42 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 43 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 44 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 45 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 46 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 47 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 48 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 49 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 50 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 51 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 52 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 53 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 54 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 55 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 56 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 57 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 58 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 59 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 60 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 61 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 62 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 63 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 64 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 65 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 66 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 67 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 68 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 69 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 70 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 71 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 72 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 73 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 74 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 75 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 76 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 77 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 78 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 79 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 80 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 81 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 82 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 83 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 84 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 85 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 86 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 87 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 88 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 89 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 90 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 91 из 100
# Добавлено позиций: 100
# Сбор позиций со страницы 92 из 100
# Добавлено позиций: 68
# Сбор позиций со страницы 93 из 100
# Добавлено позиций: 0
# Сбор данных завершен.
# Все сохранено в Елки_from_0_to_10000000.xlsx
